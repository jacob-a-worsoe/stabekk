# %%
import sys
import os

# Get the absolute path of parent folder
current_dir = os.path.abspath("")
parent_dir = os.path.join(current_dir, os.pardir)

# Add to sys.path
sys.path.append(parent_dir)

# %%
import ml_combat as ml
from ml_combat import data
from ml_combat.MetaModel import MetaModel

# %%
from prophet import Prophet
import pandas as pd
import numpy as np

# %%
from autogluon.timeseries import TimeSeriesDataFrame, TimeSeriesPredictor

# %%
df = ml.data.get_training_cleaned()
dropcols = ['snow_density:kgm3',
    'cloud_base_agl:m',
    'ceiling_height_agl:m', 'weather_data_type']
df.drop(columns=dropcols, inplace=True)
df.dropna(axis=0, subset='absolute_humidity_2m:gm3', inplace=True)

# %%
train_data = TimeSeriesDataFrame.from_data_frame(
    df.rename(columns={'y': 'target'}),
    id_column="location",
    timestamp_column="ds",
)

# %%
predictor = TimeSeriesPredictor(
    prediction_length=48,
    path="autogluon-m4-hourly",
    target="target",
    eval_metric="MASE",
    ignore_time_index=True
)

predictor.fit(
    train_data,
    presets="medium_quality",
    time_limit=60,
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="autogluon-m4-hourly"
# ================ TimeSeriesPredictor ================
# TimeSeriesPredictor.fit() called
# Setting presets to: medium_quality
# Fitting with arguments:
# {'enable_ensemble': True,
#  'evaluation_metric': 'MASE',
#  'excluded_model_types': None,
#  'hyperparameter_tune_kwargs': None,
#  'hyperparameters': 'medium_quality',
#  'num_val_windows': 1,
#  'prediction_length': 48,
#  'random_seed': None,
#  'target': 'target',
#  'time_limit': 60,
#  'verbosity': 2}
# Provided training data set with 89712 rows, 3 items (item = single time series). Average time series length is 29904.0. Data frequency is 'S'.
# =====================================================
# AutoGluon will save models to autogluon-m4-hourly/
# AutoGluon will gauge predictive performance using evaluation metric: 'MASE'
# 	This metric's sign has been flipped to adhere to being 'higher is better'. The reported score can be multiplied by -1 to get the metric value.
#
# Provided dataset contains following columns:
# 	target:           'target'
# 	past covariates:  ['absolute_humidity_2m:gm3', 'air_density_2m:kgm3', 'clear_sky_energy_1h:J', 'clear_sky_rad:W', 'dew_or_rime:idx', 'dew_point_2m:K', 'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J', 'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm', 'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm', 'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx', 'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx', 'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p', 'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa', 'snow_depth:cm', 'snow_drift:idx', 'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d', 'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K', 'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms', 'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms', 'wind_speed_w_1000hPa:ms']
#
# Starting training. Start time is 2023-11-03 14:29:10
# Models that will be trained: ['Naive', 'SeasonalNaive', 'Theta', 'AutoETS', 'RecursiveTabular', 'DeepAR']
# Training timeseries model Naive. Training for up to 58.90s of the 58.90s of remaining time.
# 	-3.7024       = Validation score (-MASE)
# 	0.12    s     = Training runtime
# 	5.42    s     = Validation (prediction) runtime
# Training timeseries model SeasonalNaive. Training for up to 53.35s of the 53.35s of remaining time.
# 	-3.7024       = Validation score (-MASE)
# 	0.11    s     = Training runtime
# 	3.92    s     = Validation (prediction) runtime
# Training timeseries model Theta. Training for up to 49.30s of the 49.30s of remaining time.
# 	-4.3685       = Validation score (-MASE)
# 	0.10    s     = Training runtime
# 	10.42   s     = Validation (prediction) runtime
# Training timeseries model AutoETS. Training for up to 38.77s of the 38.77s of remaining time.
# 	-3.7024       = Validation score (-MASE)
# 	0.13    s     = Training runtime
# 	8.98    s     = Validation (prediction) runtime
# Training timeseries model RecursiveTabular. Training for up to 29.66s of the 29.66s of remaining time.
# 	-6.1977       = Validation score (-MASE)
# 	2.82    s     = Training runtime
# 	0.64    s     = Validation (prediction) runtime
# Training timeseries model DeepAR. Training for up to 26.19s of the 26.19s of remaining time.
# 	-2.3633       = Validation score (-MASE)
# 	26.43   s     = Training runtime
# 	0.19    s     = Validation (prediction) runtime
# Not fitting ensemble due to lack of time remaining. Time left: -0.43 seconds
# Training complete. Models trained: ['Naive', 'SeasonalNaive', 'Theta', 'AutoETS', 'RecursiveTabular', 'DeepAR']
# Total runtime: 60.24 s
# Best model: DeepAR
# Best model score: -2.3633

# %%
import matplotlib.pyplot as plt
import numpy as np

item_id = "H1"
fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=[10, 4], sharex=True)
train_ts = train_data.loc[item_id]
test_ts = test_data.loc[item_id]
ax1.set_title("Train data (past time series values)")
ax1.plot(train_ts)
ax2.set_title("Test data (past + future time series values)")
ax2.plot(test_ts)
for ax in (ax1, ax2):
    ax.fill_between(np.array([train_ts.index[-1], test_ts.index[-1]]), test_ts.min(), test_ts.max(), color="C1", alpha=0.3, label="Forecast horizon")
plt.legend()
plt.show()

# %%
for loc in ['A', 'B', 'C']:
    df['y_lagged_1yr'] = df.y.shift(-365*34)
# Out:
#        location                  ds      y  absolute_humidity_2m:gm3  \
# 0             A 2019-06-02 22:00:00   0.00                     7.700
# 1             A 2019-06-02 23:00:00   0.00                     7.700
# 2             A 2019-06-03 00:00:00   0.00                     7.875
# 3             A 2019-06-03 01:00:00   0.00                     8.425
# 4             A 2019-06-03 02:00:00  19.36                     8.950
# ...         ...                 ...    ...                       ...
# 101358        C 2023-04-30 19:00:00  50.96                     4.400
# 101359        C 2023-04-30 20:00:00   2.94                     4.400
# 101360        C 2023-04-30 21:00:00   0.00                     4.400
# 101361        C 2023-04-30 22:00:00   0.00                     4.400
# 101362        C 2023-04-30 23:00:00   0.00                     4.400
#
#         air_density_2m:kgm3  clear_sky_energy_1h:J  clear_sky_rad:W  \
# 0                   1.22825               0.000000            0.000
# 1                   1.22350               0.000000            0.000
# 2                   1.21975               0.000000            0.000
# 3                   1.21800             208.649994            0.750
# 4                   1.21800           32468.150269           23.100
# ...                     ...                    ...              ...
# 101358              1.27550           84010.151367            4.175
# 101359              1.27850            2206.800018            0.000
# 101360              1.27900               0.000000            0.000
# 101361              1.27975               0.000000            0.000
# 101362              1.27975               0.000000            0.000
#
#         dew_or_rime:idx  dew_point_2m:K  diffuse_rad:W  ...  sun_azimuth:d  \
# 0                   0.0      280.299988          0.000  ...     348.036758
# 1                   0.0      280.299988          0.000  ...      91.980751
# 2                   0.0      280.650002          0.000  ...      14.934750
# 3                   0.0      281.674995          0.300  ...      28.630250
# 4                   0.0      282.500000         11.975  ...      41.997500
# ...                 ...             ...            ...  ...            ...
# 101358              0.0      272.025002          2.775  ...     304.936501
# 101359              0.0      271.949997          0.000  ...     318.620499
# 101360              0.0      271.899994          0.000  ...     332.780251
# 101361              0.0      271.949997          0.000  ...     347.373245
# 101362              0.0      271.949997          0.000  ...      92.206501
#
#         sun_elevation:d  super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# 0              -3.77425                           0.000   286.224998
# 1              -4.35725                           0.000   286.899994
# 2              -3.30950                           0.000   286.949997
# 3              -0.82250                           0.000   286.750000
# 4               3.05125                           0.000   286.449997
# ...                 ...                             ...          ...
# 101358         -0.20150                           0.000   274.925003
# 101359         -5.20400                           0.000   274.575005
# 101360         -8.98450                           0.025   274.399994
# 101361        -11.27050                           0.125   274.225006
# 101362        -11.88000                           0.125   274.175011
#
#         total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# 0                100.000000  40386.475586              3.600
# 1                100.000000  33770.649414              3.350
# 2                100.000000  13595.500000              3.050
# 3                100.000000   2321.850037              2.725
# 4                 99.225000  11634.799683              2.550
# ...                     ...           ...                ...
# 101358            97.725000  25027.999512              4.075
# 101359            95.850002  23995.599609              3.600
# 101360            95.925001  23068.600098              3.600
# 101361            99.425001  11856.700195              3.275
# 101362            99.875000  11125.899902              2.925
#
#         wind_speed_u_10m:ms  wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms
# 0                    -3.575               -0.500                      0.0
# 1                    -3.350                0.275                      0.0
# 2                    -2.950                0.750                      0.0
# 3                    -2.600                0.875                      0.0
# 4                    -2.350                0.925                      0.0
# ...                     ...                  ...                      ...
# 101358                3.600                1.875                      0.0
# 101359                2.950                2.125                      0.0
# 101360                2.625                2.400                      0.0
# 101361                2.325                2.325                      0.0
# 101362                1.925                2.225                      0.0
#
# [89712 rows x 45 columns]

# %%
df = df[df.location == 'A']
# Calculate the lag based on one year
one_year_lag = pd.DateOffset(years=1)

# Create a one-year lagged feature
df['ds_lagged_1yr'] = df['ds'] - one_year_lag

# Merge the lagged feature back to the original DataFrame
lagged_df = df.merge(df[['ds', 'y']], left_on='ds_lagged_1yr', right_on='ds', how='left')
lagged_df = lagged_df.rename(columns={'y_x': 'y', 'y_y': 'y_lagged_1yr'})
lagged_df = lagged_df.drop(columns=['ds_y'])
# Out:
# /var/folders/rn/zrxftcb56xg254wsfbhrtbt80000gn/T/ipykernel_2544/606910778.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ds_lagged_1yr'] = df['ds'] - one_year_lag

# %%
lagged_df.corr()
# Out:
# /var/folders/rn/zrxftcb56xg254wsfbhrtbt80000gn/T/ipykernel_2544/2746694946.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   lagged_df.corr()
#                                        y  absolute_humidity_2m:gm3  \
# y                               1.000000                  0.237477
# absolute_humidity_2m:gm3        0.237477                  1.000000
# air_density_2m:kgm3            -0.367847                 -0.811902
# clear_sky_energy_1h:J           0.798949                  0.366492
# clear_sky_rad:W                 0.811664                  0.363609
# dew_or_rime:idx                -0.059754                  0.134031
# dew_point_2m:K                  0.247368                  0.974455
# diffuse_rad:W                   0.708496                  0.295421
# diffuse_rad_1h:J                0.701035                  0.301467
# direct_rad:W                    0.867413                  0.244952
# direct_rad_1h:J                 0.853149                  0.249241
# effective_cloud_cover:p        -0.223651                  0.033620
# elevation:m                          NaN                       NaN
# fresh_snow_12h:cm              -0.065680                 -0.147962
# fresh_snow_1h:cm               -0.046758                 -0.093656
# fresh_snow_24h:cm              -0.081308                 -0.182571
# fresh_snow_3h:cm               -0.053860                 -0.108215
# fresh_snow_6h:cm               -0.059882                 -0.123652
# is_day:idx                      0.556254                  0.314829
# is_in_shadow:idx               -0.590198                 -0.333471
# msl_pressure:hPa                0.182078                  0.136370
# precip_5min:mm                 -0.069236                  0.089157
# precip_type_5min:idx           -0.099771                 -0.015002
# pressure_100m:hPa               0.182554                  0.154096
# pressure_50m:hPa                0.177604                  0.143009
# prob_rime:p                    -0.043527                 -0.055733
# rain_water:kgm2                -0.077309                  0.275549
# relative_humidity_1000hPa:p    -0.395209                  0.167678
# sfc_pressure:hPa                0.172647                  0.131932
# snow_depth:cm                  -0.065457                 -0.209060
# snow_drift:idx                       NaN                       NaN
# snow_melt_10min:mm             -0.010862                 -0.026637
# snow_water:kgm2                -0.132826                  0.048659
# sun_azimuth:d                  -0.016277                  0.023158
# sun_elevation:d                 0.688040                  0.435043
# super_cooled_liquid_water:kgm2 -0.119872                  0.143552
# t_1000hPa:K                     0.348635                  0.907406
# total_cloud_cover:p            -0.193119                  0.057273
# visibility:m                    0.245593                 -0.157999
# wind_speed_10m:ms              -0.081860                 -0.137928
# wind_speed_u_10m:ms            -0.057263                  0.085977
# wind_speed_v_10m:ms            -0.273952                 -0.250425
# wind_speed_w_1000hPa:ms        -0.005179                  0.006652
# y_lagged_1yr                    0.674802                  0.274030
#
#                                 air_density_2m:kgm3  clear_sky_energy_1h:J  \
# y                                         -0.367847               0.798949
# absolute_humidity_2m:gm3                  -0.811902               0.366492
# air_density_2m:kgm3                        1.000000              -0.474561
# clear_sky_energy_1h:J                     -0.474561               1.000000
# clear_sky_rad:W                           -0.464314               0.992466
# dew_or_rime:idx                           -0.068119              -0.072420
# dew_point_2m:K                            -0.845149               0.370643
# diffuse_rad:W                             -0.403717               0.912896
# diffuse_rad_1h:J                          -0.416450               0.923219
# direct_rad:W                              -0.384466               0.725529
# direct_rad_1h:J                           -0.399227               0.736953
# effective_cloud_cover:p                   -0.090671              -0.005036
# elevation:m                                     NaN                    NaN
# fresh_snow_12h:cm                          0.090269              -0.073012
# fresh_snow_1h:cm                           0.062376              -0.054098
# fresh_snow_24h:cm                          0.114850              -0.088697
# fresh_snow_3h:cm                           0.070932              -0.062082
# fresh_snow_6h:cm                           0.079195              -0.068047
# is_day:idx                                -0.393754               0.667558
# is_in_shadow:idx                           0.409510              -0.706855
# msl_pressure:hPa                           0.287608               0.151694
# precip_5min:mm                            -0.106219              -0.007615
# precip_type_5min:idx                      -0.026779              -0.034854
# pressure_100m:hPa                          0.271020               0.154711
# pressure_50m:hPa                           0.282951               0.148424
# prob_rime:p                                0.072698              -0.053762
# rain_water:kgm2                           -0.178576               0.060561
# relative_humidity_1000hPa:p                0.112840              -0.326641
# sfc_pressure:hPa                           0.294801               0.142135
# snow_depth:cm                              0.276507              -0.081001
# snow_drift:idx                                  NaN                    NaN
# snow_melt_10min:mm                         0.004091              -0.012365
# snow_water:kgm2                           -0.084982              -0.033472
# sun_azimuth:d                             -0.067256               0.057467
# sun_elevation:d                           -0.498803               0.837526
# super_cooled_liquid_water:kgm2            -0.092952               0.025676
# t_1000hPa:K                               -0.914967               0.443913
# total_cloud_cover:p                       -0.124434               0.001641
# visibility:m                              -0.004826               0.081559
# wind_speed_10m:ms                         -0.036096               0.010348
# wind_speed_u_10m:ms                       -0.011786               0.075354
# wind_speed_v_10m:ms                        0.140529              -0.341231
# wind_speed_w_1000hPa:ms                   -0.002249              -0.004584
# y_lagged_1yr                              -0.360410               0.806224
#
#                                 clear_sky_rad:W  dew_or_rime:idx  \
# y                                      0.811664        -0.059754
# absolute_humidity_2m:gm3               0.363609         0.134031
# air_density_2m:kgm3                   -0.464314        -0.068119
# clear_sky_energy_1h:J                  0.992466        -0.072420
# clear_sky_rad:W                        1.000000        -0.071797
# dew_or_rime:idx                       -0.071797         1.000000
# dew_point_2m:K                         0.367717         0.134111
# diffuse_rad:W                          0.918973        -0.073139
# diffuse_rad_1h:J                       0.915726        -0.074761
# direct_rad:W                           0.732751        -0.050493
# direct_rad_1h:J                        0.732921        -0.051397
# effective_cloud_cover:p               -0.004301        -0.040830
# elevation:m                                 NaN              NaN
# fresh_snow_12h:cm                     -0.071346        -0.018729
# fresh_snow_1h:cm                      -0.053539        -0.013414
# fresh_snow_24h:cm                     -0.088429        -0.025846
# fresh_snow_3h:cm                      -0.061038        -0.012935
# fresh_snow_6h:cm                      -0.066601        -0.015470
# is_day:idx                             0.668383        -0.098465
# is_in_shadow:idx                      -0.710125         0.094701
# msl_pressure:hPa                       0.152285         0.019441
# precip_5min:mm                        -0.008624        -0.001412
# precip_type_5min:idx                  -0.034382        -0.013411
# pressure_100m:hPa                      0.154997         0.023297
# pressure_50m:hPa                       0.148857         0.022204
# prob_rime:p                           -0.053414        -0.225616
# rain_water:kgm2                        0.058604         0.003931
# relative_humidity_1000hPa:p           -0.301213         0.093656
# sfc_pressure:hPa                       0.142711         0.021124
# snow_depth:cm                         -0.080609        -0.032525
# snow_drift:idx                              NaN              NaN
# snow_melt_10min:mm                    -0.013272        -0.005585
# snow_water:kgm2                       -0.035646        -0.016923
# sun_azimuth:d                          0.002412        -0.038454
# sun_elevation:d                        0.841102        -0.063692
# super_cooled_liquid_water:kgm2         0.026736        -0.027722
# t_1000hPa:K                            0.430447         0.119601
# total_cloud_cover:p                    0.001741        -0.024626
# visibility:m                           0.072618        -0.033868
# wind_speed_10m:ms                      0.000892        -0.103045
# wind_speed_u_10m:ms                    0.070268        -0.031543
# wind_speed_v_10m:ms                   -0.326764         0.002082
# wind_speed_w_1000hPa:ms               -0.006520        -0.001627
# y_lagged_1yr                           0.818656        -0.060534
#
#                                 dew_point_2m:K  diffuse_rad:W  \
# y                                     0.247368       0.708496
# absolute_humidity_2m:gm3              0.974455       0.295421
# air_density_2m:kgm3                  -0.845149      -0.403717
# clear_sky_energy_1h:J                 0.370643       0.912896
# clear_sky_rad:W                       0.367717       0.918973
# dew_or_rime:idx                       0.134111      -0.073139
# dew_point_2m:K                        1.000000       0.303208
# diffuse_rad:W                         0.303208       1.000000
# diffuse_rad_1h:J                      0.309298       0.988092
# direct_rad:W                          0.246306       0.563216
# direct_rad_1h:J                       0.250803       0.568745
# effective_cloud_cover:p               0.073079       0.068847
# elevation:m                                NaN            NaN
# fresh_snow_12h:cm                    -0.153985      -0.057293
# fresh_snow_1h:cm                     -0.099836      -0.051924
# fresh_snow_24h:cm                    -0.190566      -0.069572
# fresh_snow_3h:cm                     -0.114433      -0.057411
# fresh_snow_6h:cm                     -0.129762      -0.058886
# is_day:idx                            0.317575       0.687288
# is_in_shadow:idx                     -0.336498      -0.726152
# msl_pressure:hPa                      0.126601       0.129231
# precip_5min:mm                        0.087628      -0.019132
# precip_type_5min:idx                 -0.011626      -0.038344
# pressure_100m:hPa                     0.144890       0.131033
# pressure_50m:hPa                      0.133372       0.125739
# prob_rime:p                          -0.049990      -0.054504
# rain_water:kgm2                       0.251116      -0.021746
# relative_humidity_1000hPa:p           0.168462      -0.289476
# sfc_pressure:hPa                      0.121868       0.120438
# snow_depth:cm                        -0.271772      -0.063866
# snow_drift:idx                             NaN            NaN
# snow_melt_10min:mm                   -0.021648      -0.006317
# snow_water:kgm2                       0.064167      -0.079097
# sun_azimuth:d                         0.023244       0.004464
# sun_elevation:d                       0.439539       0.806737
# super_cooled_liquid_water:kgm2        0.175667      -0.053111
# t_1000hPa:K                           0.923649       0.357530
# total_cloud_cover:p                   0.093788       0.085366
# visibility:m                         -0.182689       0.095721
# wind_speed_10m:ms                    -0.091685      -0.001287
# wind_speed_u_10m:ms                   0.127190       0.068402
# wind_speed_v_10m:ms                  -0.235942      -0.298511
# wind_speed_w_1000hPa:ms               0.008510      -0.004533
# y_lagged_1yr                          0.278184       0.758452
#
#                                 diffuse_rad_1h:J  direct_rad:W  ...  \
# y                                       0.701035      0.867413  ...
# absolute_humidity_2m:gm3                0.301467      0.244952  ...
# air_density_2m:kgm3                    -0.416450     -0.384466  ...
# clear_sky_energy_1h:J                   0.923219      0.725529  ...
# clear_sky_rad:W                         0.915726      0.732751  ...
# dew_or_rime:idx                        -0.074761     -0.050493  ...
# dew_point_2m:K                          0.309298      0.246306  ...
# diffuse_rad:W                           0.988092      0.563216  ...
# diffuse_rad_1h:J                        1.000000      0.564083  ...
# direct_rad:W                            0.564083      1.000000  ...
# direct_rad_1h:J                         0.573669      0.986608  ...
# effective_cloud_cover:p                 0.065024     -0.335557  ...
# elevation:m                                  NaN           NaN  ...
# fresh_snow_12h:cm                      -0.060215     -0.055350  ...
# fresh_snow_1h:cm                       -0.053149     -0.039824  ...
# fresh_snow_24h:cm                      -0.070552     -0.069131  ...
# fresh_snow_3h:cm                       -0.059665     -0.045761  ...
# fresh_snow_6h:cm                       -0.061806     -0.050441  ...
# is_day:idx                              0.687819      0.470233  ...
# is_in_shadow:idx                       -0.722145     -0.501038  ...
# msl_pressure:hPa                        0.129953      0.179177  ...
# precip_5min:mm                         -0.017436     -0.059081  ...
# precip_type_5min:idx                   -0.038305     -0.091585  ...
# pressure_100m:hPa                       0.132060      0.179941  ...
# pressure_50m:hPa                        0.126586      0.174783  ...
# prob_rime:p                            -0.055576     -0.037488  ...
# rain_water:kgm2                        -0.015125     -0.103375  ...
# relative_humidity_1000hPa:p            -0.314139     -0.447540  ...
# sfc_pressure:hPa                        0.121111      0.169627  ...
# snow_depth:cm                          -0.065030     -0.054187  ...
# snow_drift:idx                               NaN           NaN  ...
# snow_melt_10min:mm                     -0.005192     -0.007925  ...
# snow_water:kgm2                        -0.072480     -0.152517  ...
# sun_azimuth:d                           0.060719     -0.002497  ...
# sun_elevation:d                         0.807722      0.606938  ...
# super_cooled_liquid_water:kgm2         -0.049323     -0.182468  ...
# t_1000hPa:K                             0.372564      0.380728  ...
# total_cloud_cover:p                     0.080312     -0.292501  ...
# visibility:m                            0.103443      0.309994  ...
# wind_speed_10m:ms                       0.006169     -0.095268  ...
# wind_speed_u_10m:ms                     0.072707     -0.094143  ...
# wind_speed_v_10m:ms                    -0.314099     -0.276244  ...
# wind_speed_w_1000hPa:ms                -0.002331     -0.003078  ...
# y_lagged_1yr                            0.749349      0.591861  ...
#
#                                 sun_elevation:d  \
# y                                      0.688040
# absolute_humidity_2m:gm3               0.435043
# air_density_2m:kgm3                   -0.498803
# clear_sky_energy_1h:J                  0.837526
# clear_sky_rad:W                        0.841102
# dew_or_rime:idx                       -0.063692
# dew_point_2m:K                         0.439539
# diffuse_rad:W                          0.806737
# diffuse_rad_1h:J                       0.807722
# direct_rad:W                           0.606938
# direct_rad_1h:J                        0.609762
# effective_cloud_cover:p               -0.029662
# elevation:m                                 NaN
# fresh_snow_12h:cm                     -0.085301
# fresh_snow_1h:cm                      -0.070081
# fresh_snow_24h:cm                     -0.105950
# fresh_snow_3h:cm                      -0.080490
# fresh_snow_6h:cm                      -0.086529
# is_day:idx                             0.831217
# is_in_shadow:idx                      -0.826831
# msl_pressure:hPa                       0.181601
# precip_5min:mm                        -0.018838
# precip_type_5min:idx                  -0.042893
# pressure_100m:hPa                      0.185054
# pressure_50m:hPa                       0.178410
# prob_rime:p                           -0.073815
# rain_water:kgm2                        0.071702
# relative_humidity_1000hPa:p           -0.249530
# sfc_pressure:hPa                       0.171751
# snow_depth:cm                         -0.093014
# snow_drift:idx                              NaN
# snow_melt_10min:mm                    -0.009220
# snow_water:kgm2                       -0.044413
# sun_azimuth:d                          0.004097
# sun_elevation:d                        1.000000
# super_cooled_liquid_water:kgm2         0.029530
# t_1000hPa:K                            0.474891
# total_cloud_cover:p                   -0.025738
# visibility:m                           0.036795
# wind_speed_10m:ms                     -0.019643
# wind_speed_u_10m:ms                    0.083510
# wind_speed_v_10m:ms                   -0.336297
# wind_speed_w_1000hPa:ms                0.002066
# y_lagged_1yr                           0.692263
#
#                                 super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# y                                                    -0.119872     0.348635
# absolute_humidity_2m:gm3                              0.143552     0.907406
# air_density_2m:kgm3                                  -0.092952    -0.914967
# clear_sky_energy_1h:J                                 0.025676     0.443913
# clear_sky_rad:W                                       0.026736     0.430447
# dew_or_rime:idx                                      -0.027722     0.119601
# dew_point_2m:K                                        0.175667     0.923649
# diffuse_rad:W                                        -0.053111     0.357530
# diffuse_rad_1h:J                                     -0.049323     0.372564
# direct_rad:W                                         -0.182468     0.380728
# direct_rad_1h:J                                      -0.180511     0.400298
# effective_cloud_cover:p                               0.449987    -0.060032
# elevation:m                                                NaN          NaN
# fresh_snow_12h:cm                                    -0.026463    -0.150008
# fresh_snow_1h:cm                                     -0.026631    -0.096992
# fresh_snow_24h:cm                                    -0.027208    -0.183677
# fresh_snow_3h:cm                                     -0.026696    -0.112375
# fresh_snow_6h:cm                                     -0.029775    -0.127768
# is_day:idx                                            0.022480     0.341141
# is_in_shadow:idx                                     -0.023161    -0.360511
# msl_pressure:hPa                                     -0.020814     0.045808
# precip_5min:mm                                        0.123916     0.079822
# precip_type_5min:idx                                  0.109132    -0.038502
# pressure_100m:hPa                                    -0.019076     0.064816
# pressure_50m:hPa                                     -0.020208     0.052661
# prob_rime:p                                          -0.041867    -0.038538
# rain_water:kgm2                                       0.366871     0.175213
# relative_humidity_1000hPa:p                           0.286298    -0.170390
# sfc_pressure:hPa                                     -0.021348     0.040540
# snow_depth:cm                                        -0.057506    -0.256025
# snow_drift:idx                                             NaN          NaN
# snow_melt_10min:mm                                    0.018735    -0.014054
# snow_water:kgm2                                       0.348407     0.007502
# sun_azimuth:d                                        -0.024233     0.079769
# sun_elevation:d                                       0.029530     0.474891
# super_cooled_liquid_water:kgm2                        1.000000     0.051424
# t_1000hPa:K                                           0.051424     1.000000
# total_cloud_cover:p                                   0.360099    -0.003074
# visibility:m                                         -0.511842     0.068383
# wind_speed_10m:ms                                     0.233493    -0.112615
# wind_speed_u_10m:ms                                   0.326995    -0.037792
# wind_speed_v_10m:ms                                   0.003117    -0.157645
# wind_speed_w_1000hPa:ms                              -0.007814     0.011337
# y_lagged_1yr                                          0.024170     0.324191
#
#                                 total_cloud_cover:p  visibility:m  \
# y                                         -0.193119      0.245593
# absolute_humidity_2m:gm3                   0.057273     -0.157999
# air_density_2m:kgm3                       -0.124434     -0.004826
# clear_sky_energy_1h:J                      0.001641      0.081559
# clear_sky_rad:W                            0.001741      0.072618
# dew_or_rime:idx                           -0.024626     -0.033868
# dew_point_2m:K                             0.093788     -0.182689
# diffuse_rad:W                              0.085366      0.095721
# diffuse_rad_1h:J                           0.080312      0.103443
# direct_rad:W                              -0.292501      0.309994
# direct_rad_1h:J                           -0.285566      0.321170
# effective_cloud_cover:p                    0.936238     -0.523437
# elevation:m                                     NaN           NaN
# fresh_snow_12h:cm                          0.059123     -0.026686
# fresh_snow_1h:cm                           0.050014     -0.031159
# fresh_snow_24h:cm                          0.065020     -0.020552
# fresh_snow_3h:cm                           0.054189     -0.035675
# fresh_snow_6h:cm                           0.057468     -0.034370
# is_day:idx                                -0.015147      0.056654
# is_in_shadow:idx                           0.015214     -0.051985
# msl_pressure:hPa                          -0.227901      0.057482
# precip_5min:mm                             0.132423     -0.116562
# precip_type_5min:idx                       0.176318     -0.208228
# pressure_100m:hPa                         -0.227117      0.057296
# pressure_50m:hPa                          -0.227928      0.057008
# prob_rime:p                               -0.082244      0.000121
# rain_water:kgm2                            0.184848     -0.384992
# relative_humidity_1000hPa:p                0.255196     -0.652828
# sfc_pressure:hPa                          -0.228704      0.056704
# snow_depth:cm                             -0.052137      0.027279
# snow_drift:idx                                  NaN           NaN
# snow_melt_10min:mm                         0.020824     -0.006760
# snow_water:kgm2                            0.278906     -0.427624
# sun_azimuth:d                             -0.010558      0.079411
# sun_elevation:d                           -0.025738      0.036795
# super_cooled_liquid_water:kgm2             0.360099     -0.511842
# t_1000hPa:K                               -0.003074      0.068383
# total_cloud_cover:p                        1.000000     -0.400207
# visibility:m                              -0.400207      1.000000
# wind_speed_10m:ms                          0.224950     -0.232936
# wind_speed_u_10m:ms                        0.251498     -0.505001
# wind_speed_v_10m:ms                        0.056774      0.069546
# wind_speed_w_1000hPa:ms                   -0.020322      0.003650
# y_lagged_1yr                               0.015242      0.053636
#
#                                 wind_speed_10m:ms  wind_speed_u_10m:ms  \
# y                                       -0.081860            -0.057263
# absolute_humidity_2m:gm3                -0.137928             0.085977
# air_density_2m:kgm3                     -0.036096            -0.011786
# clear_sky_energy_1h:J                    0.010348             0.075354
# clear_sky_rad:W                          0.000892             0.070268
# dew_or_rime:idx                         -0.103045            -0.031543
# dew_point_2m:K                          -0.091685             0.127190
# diffuse_rad:W                           -0.001287             0.068402
# diffuse_rad_1h:J                         0.006169             0.072707
# direct_rad:W                            -0.095268            -0.094143
# direct_rad_1h:J                         -0.085255            -0.090513
# effective_cloud_cover:p                  0.281043             0.343320
# elevation:m                                   NaN                  NaN
# fresh_snow_12h:cm                        0.071577             0.021241
# fresh_snow_1h:cm                         0.047356             0.010690
# fresh_snow_24h:cm                        0.078455             0.018116
# fresh_snow_3h:cm                         0.054743             0.015480
# fresh_snow_6h:cm                         0.061277             0.019029
# is_day:idx                               0.001584             0.066975
# is_in_shadow:idx                         0.002460            -0.071564
# msl_pressure:hPa                        -0.201968             0.073626
# precip_5min:mm                           0.098280             0.028396
# precip_type_5min:idx                     0.160665             0.112520
# pressure_100m:hPa                       -0.204446             0.072666
# pressure_50m:hPa                        -0.204167             0.072312
# prob_rime:p                             -0.078579            -0.032378
# rain_water:kgm2                          0.064354             0.112902
# relative_humidity_1000hPa:p              0.002977             0.332993
# sfc_pressure:hPa                        -0.203844             0.071977
# snow_depth:cm                           -0.019489            -0.013215
# snow_drift:idx                                NaN                  NaN
# snow_melt_10min:mm                       0.009650            -0.007218
# snow_water:kgm2                          0.185180             0.099247
# sun_azimuth:d                            0.048514             0.027387
# sun_elevation:d                         -0.019643             0.083510
# super_cooled_liquid_water:kgm2           0.233493             0.326995
# t_1000hPa:K                             -0.112615            -0.037792
# total_cloud_cover:p                      0.224950             0.251498
# visibility:m                            -0.232936            -0.505001
# wind_speed_10m:ms                        1.000000             0.498458
# wind_speed_u_10m:ms                      0.498458             1.000000
# wind_speed_v_10m:ms                      0.075861            -0.070715
# wind_speed_w_1000hPa:ms                 -0.007347            -0.005765
# y_lagged_1yr                             0.016993             0.057200
#
#                                 wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms  \
# y                                         -0.273952                -0.005179
# absolute_humidity_2m:gm3                  -0.250425                 0.006652
# air_density_2m:kgm3                        0.140529                -0.002249
# clear_sky_energy_1h:J                     -0.341231                -0.004584
# clear_sky_rad:W                           -0.326764                -0.006520
# dew_or_rime:idx                            0.002082                -0.001627
# dew_point_2m:K                            -0.235942                 0.008510
# diffuse_rad:W                             -0.298511                -0.004533
# diffuse_rad_1h:J                          -0.314099                -0.002331
# direct_rad:W                              -0.276244                -0.003078
# direct_rad_1h:J                           -0.288770                -0.000072
# effective_cloud_cover:p                    0.046840                -0.022322
# elevation:m                                     NaN                      NaN
# fresh_snow_12h:cm                          0.019376                -0.002164
# fresh_snow_1h:cm                           0.011946                -0.001291
# fresh_snow_24h:cm                          0.027348                -0.002728
# fresh_snow_3h:cm                           0.009807                -0.001519
# fresh_snow_6h:cm                           0.010020                -0.001766
# is_day:idx                                -0.267717                 0.007200
# is_in_shadow:idx                           0.281314                -0.006924
# msl_pressure:hPa                          -0.214315                 0.020397
# precip_5min:mm                             0.031539                -0.002904
# precip_type_5min:idx                       0.013574                -0.004014
# pressure_100m:hPa                         -0.215033                 0.020655
# pressure_50m:hPa                          -0.212683                 0.020537
# prob_rime:p                                0.009742                -0.001207
# rain_water:kgm2                           -0.038522                -0.003579
# relative_humidity_1000hPa:p               -0.079398                -0.018229
# sfc_pressure:hPa                          -0.210285                 0.020434
# snow_depth:cm                              0.061630                -0.002289
# snow_drift:idx                                  NaN                      NaN
# snow_melt_10min:mm                         0.024211                -0.000701
# snow_water:kgm2                            0.073480                -0.005508
# sun_azimuth:d                             -0.074834                 0.018982
# sun_elevation:d                           -0.336297                 0.002066
# super_cooled_liquid_water:kgm2             0.003117                -0.007814
# t_1000hPa:K                               -0.157645                 0.011337
# total_cloud_cover:p                        0.056774                -0.020322
# visibility:m                               0.069546                 0.003650
# wind_speed_10m:ms                          0.075861                -0.007347
# wind_speed_u_10m:ms                       -0.070715                -0.005765
# wind_speed_v_10m:ms                        1.000000                -0.018380
# wind_speed_w_1000hPa:ms                   -0.018380                 1.000000
# y_lagged_1yr                              -0.270047                -0.005232
#
#                                 y_lagged_1yr
# y                                   0.674802
# absolute_humidity_2m:gm3            0.274030
# air_density_2m:kgm3                -0.360410
# clear_sky_energy_1h:J               0.806224
# clear_sky_rad:W                     0.818656
# dew_or_rime:idx                    -0.060534
# dew_point_2m:K                      0.278184
# diffuse_rad:W                       0.758452
# diffuse_rad_1h:J                    0.749349
# direct_rad:W                        0.591861
# direct_rad_1h:J                     0.587768
# effective_cloud_cover:p             0.007247
# elevation:m                              NaN
# fresh_snow_12h:cm                  -0.064010
# fresh_snow_1h:cm                   -0.048120
# fresh_snow_24h:cm                  -0.069896
# fresh_snow_3h:cm                   -0.054376
# fresh_snow_6h:cm                   -0.059120
# is_day:idx                          0.558350
# is_in_shadow:idx                   -0.592524
# msl_pressure:hPa                    0.100018
# precip_5min:mm                      0.004971
# precip_type_5min:idx               -0.025966
# pressure_100m:hPa                   0.102028
# pressure_50m:hPa                    0.096981
# prob_rime:p                        -0.043981
# rain_water:kgm2                     0.047433
# relative_humidity_1000hPa:p        -0.229090
# sfc_pressure:hPa                    0.091921
# snow_depth:cm                      -0.059079
# snow_drift:idx                           NaN
# snow_melt_10min:mm                 -0.012874
# snow_water:kgm2                    -0.015774
# sun_azimuth:d                      -0.015768
# sun_elevation:d                     0.692263
# super_cooled_liquid_water:kgm2      0.024170
# t_1000hPa:K                         0.324191
# total_cloud_cover:p                 0.015242
# visibility:m                        0.053636
# wind_speed_10m:ms                   0.016993
# wind_speed_u_10m:ms                 0.057200
# wind_speed_v_10m:ms                -0.270047
# wind_speed_w_1000hPa:ms            -0.005232
# y_lagged_1yr                        1.000000
#
# [44 rows x 44 columns]

# %%
df = ml.data.get_training_cleaned()

lagged_dfs = []  # A list to store lagged DataFrames for each location

# Calculate the lag based on one year
one_year_lag = pd.DateOffset(years=1)

# Iterate over unique locations
for location in df['location'].unique():
    location_df = df[df['location'] == location]  # Filter by location
    
    # Create a one-year lagged feature for this location
    location_df['ds_lagged_1yr'] = location_df['ds'] - one_year_lag
    
    # Merge the lagged feature back to the original DataFrame
    lagged_location_df = location_df.merge(location_df[['ds', 'y']], left_on='ds_lagged_1yr', right_on='ds', how='left')
    lagged_location_df = lagged_location_df.rename(columns={'y_x': 'y', 'y_y': 'y_lagged_1yr', 'ds_x': 'ds'})
    lagged_location_df = lagged_location_df.drop(columns=['ds_y', 'ds_lagged_1yr'])
    
    lagged_dfs.append(lagged_location_df)

# Combine all the lagged DataFrames for different locations
result_df = pd.concat(lagged_dfs)
# Out:
# /var/folders/rn/zrxftcb56xg254wsfbhrtbt80000gn/T/ipykernel_2544/936998059.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   location_df['ds_lagged_1yr'] = location_df['ds'] - one_year_lag
# /var/folders/rn/zrxftcb56xg254wsfbhrtbt80000gn/T/ipykernel_2544/936998059.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   location_df['ds_lagged_1yr'] = location_df['ds'] - one_year_lag
# /var/folders/rn/zrxftcb56xg254wsfbhrtbt80000gn/T/ipykernel_2544/936998059.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   location_df['ds_lagged_1yr'] = location_df['ds'] - one_year_lag

# %%
result_df
# Out:
#       location                  ds      y weather_data_type  \
# 0            A 2019-06-02 22:00:00   0.00          observed
# 1            A 2019-06-02 23:00:00   0.00          observed
# 2            A 2019-06-03 00:00:00   0.00          observed
# 3            A 2019-06-03 01:00:00   0.00          observed
# 4            A 2019-06-03 02:00:00  19.36          observed
# ...        ...                 ...    ...               ...
# 26021        C 2023-04-30 19:00:00  50.96         estimated
# 26022        C 2023-04-30 20:00:00   2.94         estimated
# 26023        C 2023-04-30 21:00:00   0.00         estimated
# 26024        C 2023-04-30 22:00:00   0.00         estimated
# 26025        C 2023-04-30 23:00:00   0.00         estimated
#
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 0                         7.700              1.22825           1728.950012
# 1                         7.700              1.22350           1689.824982
# 2                         7.875              1.21975           1563.225006
# 3                         8.425              1.21800           1283.425018
# 4                         8.950              1.21800           1003.500000
# ...                         ...                  ...                   ...
# 26021                     4.400              1.27550           1456.574982
# 26022                     4.400              1.27850           1476.350006
# 26023                     4.400              1.27900           1516.299988
# 26024                     4.400              1.27975           1240.600006
# 26025                     4.400              1.27975           1484.500015
#
#        clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  ...  \
# 0                   0.000000            0.000       1728.950012  ...
# 1                   0.000000            0.000       1689.824982  ...
# 2                   0.000000            0.000       1563.225006  ...
# 3                 208.649994            0.750       1283.425018  ...
# 4               32468.150269           23.100       1003.500000  ...
# ...                      ...              ...               ...  ...
# 26021           84010.151367            4.175        551.224991  ...
# 26022            2206.800018            0.000        564.099991  ...
# 26023               0.000000            0.000        578.699997  ...
# 26024               0.000000            0.000        551.500000  ...
# 26025               0.000000            0.000        558.674988  ...
#
#        sun_elevation:d  super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# 0             -3.77425                           0.000   286.224998
# 1             -4.35725                           0.000   286.899994
# 2             -3.30950                           0.000   286.949997
# 3             -0.82250                           0.000   286.750000
# 4              3.05125                           0.000   286.449997
# ...                ...                             ...          ...
# 26021         -0.20150                           0.000   274.925003
# 26022         -5.20400                           0.000   274.575005
# 26023         -8.98450                           0.025   274.399994
# 26024        -11.27050                           0.125   274.225006
# 26025        -11.88000                           0.125   274.175011
#
#        total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# 0               100.000000  40386.475586              3.600
# 1               100.000000  33770.649414              3.350
# 2               100.000000  13595.500000              3.050
# 3               100.000000   2321.850037              2.725
# 4                99.225000  11634.799683              2.550
# ...                    ...           ...                ...
# 26021            97.725000  25027.999512              4.075
# 26022            95.850002  23995.599609              3.600
# 26023            95.925001  23068.600098              3.600
# 26024            99.425001  11856.700195              3.275
# 26025            99.875000  11125.899902              2.925
#
#        wind_speed_u_10m:ms  wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms  \
# 0                   -3.575               -0.500                      0.0
# 1                   -3.350                0.275                      0.0
# 2                   -2.950                0.750                      0.0
# 3                   -2.600                0.875                      0.0
# 4                   -2.350                0.925                      0.0
# ...                    ...                  ...                      ...
# 26021                3.600                1.875                      0.0
# 26022                2.950                2.125                      0.0
# 26023                2.625                2.400                      0.0
# 26024                2.325                2.325                      0.0
# 26025                1.925                2.225                      0.0
#
#        y_lagged_1yr
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 26021           NaN
# 26022           NaN
# 26023           NaN
# 26024           NaN
# 26025           NaN
#
# [89785 rows x 50 columns]
